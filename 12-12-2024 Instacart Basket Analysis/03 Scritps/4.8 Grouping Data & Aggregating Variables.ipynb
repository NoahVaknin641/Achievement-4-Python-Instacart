# %% [markdown]
# # Reading

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\nvak6\12-12-2024 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merge.pkl'))
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             0   2539329        1             1
# 2             2             0   2539329        1             1
# 3             3             0   2539329        1             1
# 4             4             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  ...  prices match   Busiest day  Busiest days  \
# ...

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 26)

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\nvak6\AppData\Local\Temp\ipykernel_27828\1681540670.py:1: FutureWarning: The provided callable <function max at 0x000001BD6729C5E0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             0   2539329        1             1
# 2              2             0   2539329        1             1
# 3              3             0   2539329        1             1
# 4              4             0   2539329        1             1
# 5              5             1   2398795        1             2
# 6              6             1   2398795        1             2
# 7              7             1   2398795        1             2
# 8              8             1   2398795        1             2
# 9              9             1   2398795        1             2
# 10            10             1   2398795        1             2
# 11            11             2    473747        1             3
# 12            12             2    473747        1             3
# 13            13             2    473747        1             3
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             0   2539329        1             1
# 2              2             0   2539329        1             1
# 3              3             0   2539329        1             1
# 4              4             0   2539329        1             1
# 5              5             1   2398795        1             2
# 6              6             1   2398795        1             2
# 7              7             1   2398795        1             2
# 8              8             1   2398795        1             2
# 9              9             1   2398795        1             2
# 10            10             1   2398795        1             2
# 11            11             2    473747        1             3
# 12            12             2    473747        1             3
# 13            13             2    473747        1             3
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %% [markdown]
# # Task

# %%
#2
df.groupby('department_id').mean(numeric_only=True)
# Out:
#                 Unnamed: 0.1  Unnamed: 0_x      order_id      user_id  \
# department_id
# 1              497110.740371  53399.004673  1.723109e+06  3272.185384
# 2              475924.918349  51115.802752  1.756210e+06  3133.122018
# 3              502324.318685  53968.635634  1.713073e+06  3307.733286
# 4              499356.994286  53648.343362  1.709902e+06  3287.953050
# 5              492200.403166  52869.591195  1.733367e+06  3241.935372
# 6              479294.535962  51505.162346  1.724378e+06  3158.340757
# 7              508338.850338  54609.256114  1.715484e+06  3346.748640
# 8              496227.720703  53254.086669  1.668334e+06  3258.026202
# 9              500238.066592  53739.338967  1.702576e+06  3293.172526
# 10             499057.280909  53611.739091  1.677716e+06  3286.776364
# 11             488873.616510  52520.241120  1.698489e+06  3219.946007
# 12             491704.310990  52829.322863  1.709932e+06  3238.748095
# ...

# %% [markdown]
# As opposed to only showing the mean of the order_number column this line of code that was just run gives the mean of all columns within
# the data frame that contain numeric values

# %%
#4
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
#5
ords_prods_merge.groupby('loyalty_flag')['prices'].agg(['mean', 'min', 'max', 'median', 'sum'])
# Out:
#                        mean  min      max  median          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0     7.4  106814042.2
# New customer      13.294670  1.0  99999.0     7.4   83011787.2
# Regular customer  12.495717  1.0  99999.0     7.4  198391693.2

# %% [markdown]
# New customers spend the most on average followed by regular sustomers followed by loyal customers

# %%
#6
mean_price_per_user = ords_prods_merge.groupby('user_id')['prices'].mean()
ords_prods_merge.loc[ords_prods_merge['user_id'].isin(mean_price_per_user[mean_price_per_user >= 10].index), 'spending_flag'] = 'High spender'
ords_prods_merge.loc[ords_prods_merge['user_id'].isin(mean_price_per_user[mean_price_per_user < 10].index), 'spending_flag'] = 'Low spender'
ords_prods_merge['spending_flag'].value_counts(dropna=False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby('spending_flag')['prices'].mean()
# Out:
# spending_flag
# High spender    222.343698
# Low spender       7.780685
# Name: prices, dtype: float64

# %% [markdown]
# I calculated the mean price of each user. then assigned the spending flag, finally I checked the value count per flag

# %%
# Step 1: Assign "Non-frequent customer" to users with a median > 20
ords_prods_merge.loc[ords_prods_merge['days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# Step 2: Assign "Regular customer" to users with a median > 10 and <= 20
ords_prods_merge.loc[(ords_prods_merge['days_since_prior_order'] > 10) & (ords_prods_merge['days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# Step 3: Assign "Frequent customer" to users with a median <= 10
ords_prods_merge.loc[ords_prods_merge['days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# Step 4: Check the results
ords_prods_merge['order_frequency_flag'].value_counts(dropna=False)
# Out:
# order_frequency_flag
# Frequent customer        19042466
# Regular customer          6055803
# Non-frequent customer     5230494
# NaN                       2076096
# Name: count, dtype: int64

# %% [markdown]
# Step 1: Assign "Non-frequent customer" to users with a median > 20
# Step 2: Assign "Regular customer" to users with a median > 10 and <= 20
# Step 3: Assign "Frequent customer" to users with a median <= 10
# Step 4: Check the results

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merge.pkl'))

# %%
ords_prods_merge.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             0   2539329        1             1
# 2             2             0   2539329        1             1
# 3             3             0   2539329        1             1
# 4             4             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  ...  prices match   Busiest day  Busiest days  \
# ...
